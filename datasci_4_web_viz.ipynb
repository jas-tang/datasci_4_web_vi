# %% [markdown]
# <a href="https://colab.research.google.com/github/jas-tang/datasci_4_web_vi/blob/main/datasci_4_web_viz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Packages

# %% [markdown]
# Loading Packages

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !pip install ipywidgets
# !jupyter nbextension enable --py widgetsnbextension

# %%
import ipywidgets as widgets

# %% [markdown]
# #ShinyApp
# [ShinyApp](https://aeg17i-jason-tang.shinyapps.io/texas_bp/)

# %%
df = pd.read_csv("/content/sample_data/PLACES__Local_Data_for_Better_Health__County_Data_2023_release.csv")
df.sample(5)
# Out:
#         Year StateAbbr  StateDesc  LocationName DataSource         Category  \
# 180749  2020        TX      Texas        Howard      BRFSS  Health Outcomes
# 101360  2021        MN  Minnesota          Rice      BRFSS  Health Outcomes
# 59252   2021        KS     Kansas        Morris      BRFSS       Prevention
# 75702   2021        MD   Maryland  Anne Arundel      BRFSS  Health Outcomes
# 30910   2021        CO   Colorado        Pueblo      BRFSS       Disability
#
#                                                   Measure Data_Value_Unit  \
# 180749        All teeth lost among adults aged >=65 years               %
# 101360               Obesity among adults aged >=18 years               %
# 59252   Visits to doctor for routine checkup within th...               %
# 75702         Current asthma among adults aged >=18 years               %
# 30910   Cognitive disability among adults ages >=18 years               %
#
#                 Data_Value_Type  Data_Value  ...  Data_Value_Footnote  \
# 180749  Age-adjusted prevalence        15.1  ...                  NaN
# 101360         Crude prevalence        36.2  ...                  NaN
# 59252   Age-adjusted prevalence        71.8  ...                  NaN
# 75702   Age-adjusted prevalence         9.1  ...                  NaN
# 30910   Age-adjusted prevalence        14.4  ...                  NaN
#
#         Low_Confidence_Limit  High_Confidence_Limit  TotalPopulation  \
# 180749                  11.3                   19.3            34128
# 101360                  30.4                   42.6            67262
# 59252                   67.0                   76.7             5356
# 75702                    8.1                   10.1           590336
# 30910                   12.4                   16.7           169622
#
#         LocationID  CategoryID  MeasureId DataValueTypeID  \
# 180749       48227     HLTHOUT  TEETHLOST       AgeAdjPrv
# 101360       27131     HLTHOUT    OBESITY          CrdPrv
# 59252        20127     PREVENT    CHECKUP       AgeAdjPrv
# 75702        24003     HLTHOUT    CASTHMA       AgeAdjPrv
# 30910         8101     DISABLT  COGNITION       AgeAdjPrv
#
#          Short_Question_Text                      Geolocation
# 180749        All Teeth Lost  POINT (-101.4387208 32.3034298)
# 101360               Obesity    POINT (-93.298513 44.3507747)
# 59252         Annual Checkup    POINT (-96.6514482 38.688204)
# 75702         Current Asthma   POINT (-76.5608941 38.9916174)
# 30910   Cognitive Disability  POINT (-104.4846683 38.1627652)
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (228770, 21)

# %%
# Filter for 'BINGE' as measureid and 'Age-adjusted prevalence' as data_value_type
df = df[(df['StateAbbr'] == 'TX')]
df.sample(5)
# Out:
#         Year StateAbbr StateDesc   LocationName DataSource  \
# 183698  2021        TX     Texas      Fort Bend      BRFSS
# 200096  2021        TX     Texas          Upton      BRFSS
# 181662  2020        TX     Texas         Howard      BRFSS
# 183347  2021        TX     Texas         Fannin      BRFSS
# 192077  2020        TX     Texas  Collingsworth      BRFSS
#
#                      Category  \
# 183698  Health Risk Behaviors
# 200096        Health Outcomes
# 181662             Prevention
# 183347             Disability
# 192077             Prevention
#
#                                                   Measure Data_Value_Unit  \
# 183698        Binge drinking among adults aged >=18 years               %
# 200096  High cholesterol among adults aged >=18 years ...               %
# 181662  Visits to dentist or dental clinic among adult...               %
# 183347        Any disability among adults aged >=18 years               %
# 192077  Cervical cancer screening among adult women ag...               %
#
#                 Data_Value_Type  Data_Value  ...  Data_Value_Footnote  \
# 183698         Crude prevalence        15.5  ...                  NaN
# 200096         Crude prevalence        38.8  ...                  NaN
# 181662  Age-adjusted prevalence        47.1  ...                  NaN
# 183347         Crude prevalence        33.3  ...                  NaN
# 192077         Crude prevalence        76.6  ...                  NaN
#
#         Low_Confidence_Limit  High_Confidence_Limit  TotalPopulation  \
# 183698                  12.7                   18.5           858527
# 200096                  33.7                   44.2             3265
# 181662                  44.0                   50.3            34128
# 183347                  28.5                   38.4            36569
# 192077                  73.9                   79.1             2615
#
#         LocationID  CategoryID   MeasureId DataValueTypeID  \
# 183698       48157     RISKBEH       BINGE          CrdPrv
# 200096       48461     HLTHOUT    HIGHCHOL          CrdPrv
# 181662       48227     PREVENT      DENTAL       AgeAdjPrv
# 183347       48147     DISABLT  DISABILITY          CrdPrv
# 192077       48087     PREVENT    CERVICAL          CrdPrv
#
#               Short_Question_Text                      Geolocation
# 183698             Binge Drinking   POINT (-95.7710149 29.5266017)
# 200096           High Cholesterol  POINT (-102.0415461 31.3538163)
# 181662               Dental Visit  POINT (-101.4387208 32.3034298)
# 183347             Any Disability   POINT (-96.1049882 33.5911611)
# 192077  Cervical Cancer Screening  POINT (-100.2721351 34.9633577)
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (18796, 21)

# %%
df.to_csv('texascdc.csv')

# %% [markdown]
# #Python Shiny Visualization

# %%
df = df[(df['MeasureId'] == 'BPHIGH') & (df['Data_Value_Type'] == 'Age-adjusted prevalence')]
df.sample(5)
# Out:
#         Year StateAbbr StateDesc LocationName DataSource         Category  \
# 185320  2021        TX     Texas      Houston      BRFSS  Health Outcomes
# 184562  2021        TX     Texas       Morris      BRFSS  Health Outcomes
# 181797  2021        TX     Texas        Bowie      BRFSS  Health Outcomes
# 182651  2021        TX     Texas       Dimmit      BRFSS  Health Outcomes
# 191654  2021        TX     Texas       Lavaca      BRFSS  Health Outcomes
#
#                                                  Measure Data_Value_Unit  \
# 185320  High blood pressure among adults aged >=18 years               %
# 184562  High blood pressure among adults aged >=18 years               %
# 181797  High blood pressure among adults aged >=18 years               %
# 182651  High blood pressure among adults aged >=18 years               %
# 191654  High blood pressure among adults aged >=18 years               %
#
#                 Data_Value_Type  Data_Value  ...  Data_Value_Footnote  \
# 185320  Age-adjusted prevalence        37.1  ...                  NaN
# 184562  Age-adjusted prevalence        35.3  ...                  NaN
# 181797  Age-adjusted prevalence        36.0  ...                  NaN
# 182651  Age-adjusted prevalence        38.1  ...                  NaN
# 191654  Age-adjusted prevalence        32.8  ...                  NaN
#
#         Low_Confidence_Limit  High_Confidence_Limit  TotalPopulation  \
# 185320                  32.6                   41.6            22241
# 184562                  31.0                   39.9            12030
# 181797                  31.9                   41.3            92581
# 182651                  33.6                   42.9             8473
# 191654                  28.6                   37.1            20544
#
#         LocationID  CategoryID MeasureId DataValueTypeID  Short_Question_Text  \
# 185320       48225     HLTHOUT    BPHIGH       AgeAdjPrv  High Blood Pressure
# 184562       48343     HLTHOUT    BPHIGH       AgeAdjPrv  High Blood Pressure
# 181797       48037     HLTHOUT    BPHIGH       AgeAdjPrv  High Blood Pressure
# 182651       48127     HLTHOUT    BPHIGH       AgeAdjPrv  High Blood Pressure
# 191654       48285     HLTHOUT    BPHIGH       AgeAdjPrv  High Blood Pressure
#
#                            Geolocation
# 185320  POINT (-95.4215995 31.3230362)
# 184562   POINT (-94.7312653 33.116466)
# 181797   POINT (-94.422393 33.4460648)
# 182651  POINT (-99.7658713 28.4235871)
# 191654  POINT (-96.9236334 29.3825778)
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (254, 21)

# %%
# Group by 'LocationName' and get the average (or sum) 'Data_Value'
grouped = df.groupby('LocationName').Data_Value.mean().sort_values(ascending=False)
grouped
# Out:
# LocationName
# San Augustine    38.1
# Dimmit           38.1
# Newton           37.8
# Walker           37.6
# Presidio         37.6
#                  ...
# Gillespie        29.0
# Borden           28.5
# Kendall          28.2
# Travis           27.0
# Loving           25.4
# Name: Data_Value, Length: 254, dtype: float64

# %%
# Plotting
plt.figure(figsize=(30, 7))
grouped.plot(kind='bar', color='lightcoral')
plt.ylabel('Average Data Value (Age-adjusted prevalence) - Percent')
plt.xlabel('Location (County)')
plt.title('High Blood Pressure Age-adjusted Prevalence by County in TX')
plt.xticks(rotation=90)
plt.tight_layout()
#plt.savefig("high_bp_location.png")  # Saving the plot as an image
plt.show()

# %%
# Compute the average data value across all counties
avg_data_value = df['Data_Value'].mean()

# Sort the counties in ascending order for the dropdown list
sorted_counties = sorted(df['LocationName'].unique())

# Interactive selection of county for visualization using ipywidgets
@widgets.interact(County=sorted_counties)
def plot_data(County):
    county_value = df[df['LocationName'] == County]['Data_Value'].values[0]

    # Labels for bars
    labels = [County, 'Average across all counties']

    # Data values for bars
    values = [county_value, avg_data_value]

    plt.figure(figsize=(8, 6))

    # Plot the bars
    colors = ['lightcoral', 'lightblue']
    plt.bar(labels, values, color=colors)

    plt.ylabel('Data Value (Age-adjusted prevalence) - Percent')
    plt.title(f'High Blood Pressure Age-adjusted Prevalence in {County} vs Average across all counties')

    plt.tight_layout()
    plt.show()
# Out:
# interactive(children=(Dropdown(description='County', options=('Anderson', 'Andrews', 'Angelina', 'Aransas', 'A…
